# %%
quadrado_lado = int(input("informe quantos cm tem o lado do quadrado"))
multiplicacao = quadrado_lado * quadrado_lado




print(multiplicacao)
# Out:
# informe quantos cm tem o lado do quadrado 10
# 100

# %%
numero = 10

resultado_soma = numero + numero

print("o resultado da soma dos dois números é:", resultado_soma)
# Out:
# o resultado da soma dos dois números é: 20

# %%
nome = "aprendi o que era escola quando \n entrei em \t uma escola e la apredi a ler e escrevre"
print(nome)
# Out:
# aprendi o que era escola quando
#  entrei em 	 uma escola e la apredi a ler e escrevre

# %%
nome = input("nome:")
len(nome)


print(nome.split(" "))
# Out:
# nome: Roberto Naia
# ['Roberto', 'Naia']

# %%
retangulo = int(input("informe quantos cm tem o lado do retangulo"))
outrolado_retangulo = int(input("informe quantos cm tem o lado do retangulo"))
nome = ( retangulo * outrolado_retangulo)
print(nome)
# Out:
# informe quantos cm tem o lado do retangulo 6
# informe quantos cm tem o lado do retangulo 4
# 24
